# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.preprocessing import PolynomialFeatures, PowerTransformer
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
#  ## Machine Learning regressions to predict housing price

# %% [markdown]
# Columns
# id - Notice identifier. It is not unique: if the notification is updated by the real estate agency (new version of the notification) a new record is created with the same id but different dates: registration and cancellation.
#
# operation_type - Type of operation (these are all sales, can be removed).
#
# l2 - Administrative level 2: usually province
#
# l3 - Administrative level 3: usually city
#
# lat - Latitude.
#
# lon - Longitude.
#
# price - Price published in the ad.
#
# property_type - Type of property (House, Apartment, PH).
#
# rooms - Number of rooms (useful in Argentina).
#
# bathrooms - Number of bathrooms.
#
# start_date - Date when the ad was created.
#
# end_date - Date of termination of the advertisement.
#
# created_on - Date when the first version of the notice was created.
#
# surface_total - Total area in m².
#
# surface_covered - Covered area in m².
#
# title - Title of the advertisement.
#
# description - Description of the advertisement.
#
# ad_type - Type of ad (Property, Development/Project).
#
# Acknowledgements
# The data in this dataset was collected by Properati.

# %%
df = pd.read_csv('ar_properties.csv')
df
# Out:
#                               id    ad_type  start_date    end_date  \
# 0       wdQ5hWhv8P14T7Sh9g4QCg==  Propiedad  2020-12-25  9999-12-31
# 1       nnMBYZ4RMRY+vm753EtA+g==  Propiedad  2020-12-25  9999-12-31
# 2       +dnVA1K6JxzL1zAjOEQ1pA==  Propiedad  2020-12-25  2020-12-29
# 3       dLHXKN5/sRZpm9Yk0yI2nA==  Propiedad  2020-12-25  2020-12-29
# 4       wtw/k887EPipd37UYHKb1Q==  Propiedad  2020-12-25  9999-12-31
# ...                          ...        ...         ...         ...
# 999995  SEeK1Z96Q3KuTKhNyREFDg==  Propiedad  2020-05-12  2020-09-02
# 999996  9rprv1XJCeNLnJP9dgWy0A==  Propiedad  2020-05-12  2020-05-28
# 999997  ABzRp7AdRjDSFxKP1iNeYA==  Propiedad  2020-05-12  2020-08-11
# 999998  /dXMbrn3glBxu4WQBQu6IA==  Propiedad  2020-05-12  9999-12-31
# 999999  PBrDcLWfCN5M+S2mxq6TOA==  Propiedad  2020-05-12  2020-07-15
#
#         created_on        lat        lon         l1                        l2  \
# 0       2020-12-25 -32.716652 -68.642692  Argentina                   Mendoza
# 1       2020-12-25 -24.797723 -65.467514  Argentina                     Salta
# 2       2020-12-25 -34.919373 -58.020591  Argentina    Bs.As. G.B.A. Zona Sur
# 3       2020-12-25 -34.919455 -58.024807  Argentina    Bs.As. G.B.A. Zona Sur
# 4       2020-12-25 -34.364924 -58.783143  Argentina  Bs.As. G.B.A. Zona Norte
# ...            ...        ...        ...        ...                       ...
# 999995  2020-05-12 -34.900186 -56.176744    Uruguay                Montevideo
# 999996  2020-05-12 -34.886879 -56.188048    Uruguay                Montevideo
# 999997  2020-05-12 -34.891367 -56.098215    Uruguay                Montevideo
# 999998  2020-05-12 -34.462092 -57.842109    Uruguay                   Colonia
# 999999  2020-05-12 -34.885796 -56.089121    Uruguay                Montevideo
#
#               l3  ... bathrooms surface_total  surface_covered    price  \
# 0            NaN  ...       NaN         350.0            350.0      NaN
# 1            NaN  ...       NaN        1541.0           1541.0      NaN
# 2       La Plata  ...       NaN        1000.0           1000.0      NaN
# 3       La Plata  ...       NaN        1000.0           1000.0      NaN
# 4        Escobar  ...       NaN       18164.0          18164.0      NaN
# ...          ...  ...       ...           ...              ...      ...
# 999995       NaN  ...       2.0          58.0             55.0  23000.0
# 999996       NaN  ...       1.0          62.0             62.0  25000.0
# 999997       NaN  ...       2.0           NaN             85.0  48000.0
# 999998       NaN  ...       1.0         135.0            135.0  35000.0
# 999999       NaN  ...       2.0          78.0             78.0  34000.0
#
#         currency  price_period  \
# 0            NaN           NaN
# 1            NaN       Mensual
# 2            NaN       Mensual
# 3            NaN       Mensual
# 4            NaN       Mensual
# ...          ...           ...
# 999995       UYU       Mensual
# 999996       UYU       Mensual
# 999997       UYU       Mensual
# 999998       UYU       Mensual
# 999999       UYU       Mensual
#
#                                                     title  \
# 0                          Excelentes Lotes Sobre Ruta 34
# 1       TERRENO + VENTA + JARDINES DE SAN LORENZO +150...
# 2                    Lote en Venta de 1000 m2 en La Plata
# 3                    Lote en Venta de 1000 m2 en La Plata
# 4                                      PANAMERICANA 47300
# ...                                                   ...
# 999995    Apartamento en ALQUILER 2 dormitorios - Cordón:
# 999996  Apartamento alquiler a estrenar 2 dormitorios ...
# 999997                                      Casa - Malvín
# 999998                     House - Colonia del Sacramento
# 999999  Apartamento para entrar, en Punta Gorda, a met...
#
#                                               description  property_type  \
# 0       Corredor Responsable: VICTOR E. MONTIVERO - C....           Lote
# 1       Corredor Responsable: Pablo Castañeda - C.U.C....           Lote
# 2       Corredor Responsable: Rico Sebastián - Martill...           Lote
# 3       Corredor Responsable: Rico Sebastián - Martill...           Lote
# 4       Nave principal 66 x 90 m:    6005 m2 cubiertos...           Otro
# ...                                                   ...            ...
# 999995  Apartamento en ALQUILER 2 dormitorios - Cordón...   Departamento
# 999996  Apartamento moderno a estrenar de 2 dormitorio...   Departamento
# 999997  EN EL CORAZON DE MALVIN, CERCA DE TODO<br><br>...           Casa
# 999998  Casa de tres dormitorios en muy linda cuadra, ...           Casa
# 999999  Luminoso apartamento en pleno Punta Gorda, a 2...   Departamento
#
#        operation_type
# 0               Venta
# 1               Venta
# 2               Venta
# 3               Venta
# 4               Venta
# ...               ...
# 999995       Alquiler
# 999996       Alquiler
# 999997       Alquiler
# 999998       Alquiler
# 999999       Alquiler
#
# [1000000 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 25 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   id               1000000 non-null  object
#  1   ad_type          1000000 non-null  object
#  2   start_date       1000000 non-null  object
#  3   end_date         1000000 non-null  object
#  4   created_on       1000000 non-null  object
#  5   lat              849189 non-null   float64
#  6   lon              848255 non-null   float64
#  7   l1               1000000 non-null  object
#  8   l2               1000000 non-null  object
#  9   l3               946673 non-null   object
#  10  l4               239496 non-null   object
#  11  l5               5001 non-null     object
#  12  l6               0 non-null        float64
#  13  rooms            526423 non-null   float64
#  14  bedrooms         466213 non-null   float64
#  15  bathrooms        776733 non-null   float64
#  16  surface_total    379501 non-null   float64
#  17  surface_covered  381451 non-null   float64
#  18  price            963098 non-null   float64
#  19  currency         961719 non-null   object
#  20  price_period     363015 non-null   object
#  21  title            1000000 non-null  object
#  22  description      999982 non-null   object
#  23  property_type    1000000 non-null  object
#  24  operation_type   1000000 non-null  object
# dtypes: float64(9), object(16)
# memory usage: 190.7+ MB

# %%
df.isna().sum()
# Out:
# id                       0
# ad_type                  0
# start_date               0
# end_date                 0
# created_on               0
# lat                 150811
# lon                 151745
# l1                       0
# l2                       0
# l3                   53327
# l4                  760504
# l5                  994999
# l6                 1000000
# rooms               473577
# bedrooms            533787
# bathrooms           223267
# surface_total       620499
# surface_covered     618549
# price                36902
# currency             38281
# price_period        636985
# title                    0
# description             18
# property_type            0
# operation_type           0
# dtype: int64

# %% [markdown]
# Mengubah semua nilai price dalam USD

# %%
df.loc[df['currency'] == 'ARS', 'price']
# Out:
# 28        2000000.0
# 29         780000.0
# 30        1650000.0
# 31          50000.0
# 32          35000.0
#             ...
# 997658    3200000.0
# 997659     170000.0
# 997660      75000.0
# 997661      25000.0
# 997662      56000.0
# Name: price, Length: 202179, dtype: float64

# %%
for i in df['currency'].unique():
    if i == 'ARS':
        df.loc[df['currency'] == i, 'price'] =  df.loc[df['currency'] == i, 'price'] * 0.009
    elif i == 'PEN':
        df.loc[df['currency'] == i, 'price'] = df.loc[df['currency'] == i, 'price'] * 0.27
    elif i == 'UYU':
        df.loc[df['currency'] == i, 'price'] = df.loc[df['currency'] == i, 'price'] * 0.024
    else:
        df.loc[df['currency'] == i, 'price'] = df.loc[df['currency'] == i, 'price']

# %%
df.loc[df['currency'] == 'ARS', 'price']
# Out:
# 28        18000.0
# 29         7020.0
# 30        14850.0
# 31          450.0
# 32          315.0
#            ...
# 997658    28800.0
# 997659     1530.0
# 997660      675.0
# 997661      225.0
# 997662      504.0
# Name: price, Length: 202179, dtype: float64

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# Kolom Id dan ad_type akan di drop(ad_type di drop karena hanya memiliki 1 jenis value (tidak memberikan informasi))

# %%
df['ad_type'].unique() ## akan di drop karena hanya memiliki 1 jenis value (tidak memberikan informasi)
# Out:
# array(['Propiedad'], dtype=object)

# %%
df.drop(columns=['ad_type','id'], inplace = True)

# %% [markdown]
# start_date, end_date, dan created_on tidak memberikan informasi yang relevan terhadap harga rumah (bergantung kepada si pembuat ads). begitu juga dengan period_price(asumsi : bias dapat merupakan harga sewa iklan)

# %%
df.drop(columns =['start_date', 'end_date', 'created_on', 'price_period'], inplace = True)

# %%
missing_percentage = df.isnull().sum()*100/len(df.index)
missing_percentage
# Out:
# lat                 15.0811
# lon                 15.1745
# l1                   0.0000
# l2                   0.0000
# l3                   5.3327
# l4                  76.0504
# l5                  99.4999
# l6                 100.0000
# rooms               47.3577
# bedrooms            53.3787
# bathrooms           22.3267
# surface_total       62.0499
# surface_covered     61.8549
# price                3.6902
# currency             3.8281
# title                0.0000
# description          0.0018
# property_type        0.0000
# operation_type       0.0000
# dtype: float64

# %% [markdown]
# l4, l5, l6 merupakan informasi yang spesifik namun memiliki missing value yang besar

# %%
df.drop(columns=['l4', 'l5', 'l6'], inplace = True)

# %% [markdown]
# kolom currency, title, dan description akan di drop. karena currency hanya sebagai data pendukung untuk mengubah price. sedangkan title dan description sangat kompleks untuk dilakukan analisis dengan unique value yang besar.

# %%
df.drop(columns = ['currency', 'title', 'description'], inplace = True)

# %%
df.isna().sum()
# Out:
# lat                150811
# lon                151745
# l1                      0
# l2                      0
# l3                  53327
# rooms              473577
# bedrooms           533787
# bathrooms          223267
# surface_total      620499
# surface_covered    618549
# price               36902
# property_type           0
# operation_type          0
# dtype: int64

# %% [markdown]
# ## Handling Missing Value

# %% [markdown]
# Mengisi Missing Value untuk feature yang belum terisi, dengan catatan:
# - mean untuk data continous numerik
# - median untuk data diskrit numerik
# - modus untuk data string/object

# %%
data ={
    'lat' : df['lat'].mean(),
    'lon' : df['lon'].mean(),
    'l3' : df['l3'].mode()[0],
    'rooms' : df['rooms'].median(),
    'bedrooms' : df['bedrooms'].median(),
    'bathrooms' : df['bathrooms'].median(),
    'surface_total' : df['surface_total'].mean(),
    'surface_covered' : df['surface_covered'].mean()
}

# %%
df.fillna(data, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   lat              1000000 non-null  float64
#  1   lon              1000000 non-null  float64
#  2   l1               1000000 non-null  object
#  3   l2               1000000 non-null  object
#  4   l3               1000000 non-null  object
#  5   rooms            1000000 non-null  float64
#  6   bedrooms         1000000 non-null  float64
#  7   bathrooms        1000000 non-null  float64
#  8   surface_total    1000000 non-null  float64
#  9   surface_covered  1000000 non-null  float64
#  10  price            963098 non-null   float64
#  11  property_type    1000000 non-null  object
#  12  operation_type   1000000 non-null  object
# dtypes: float64(8), object(5)
# memory usage: 99.2+ MB

# %% [markdown]
# Menghapus data yang kolom price nya memiliki missing value

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 963098 entries, 23 to 999999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   lat              963098 non-null  float64
#  1   lon              963098 non-null  float64
#  2   l1               963098 non-null  object
#  3   l2               963098 non-null  object
#  4   l3               963098 non-null  object
#  5   rooms            963098 non-null  float64
#  6   bedrooms         963098 non-null  float64
#  7   bathrooms        963098 non-null  float64
#  8   surface_total    963098 non-null  float64
#  9   surface_covered  963098 non-null  float64
#  10  price            963098 non-null  float64
#  11  property_type    963098 non-null  object
#  12  operation_type   963098 non-null  object
# dtypes: float64(8), object(5)
# memory usage: 102.9+ MB

# %%
### Encoding

# %%
## Check Object Info
col = ['l1', 'l2', 'l3', 'property_type', 'operation_type']
listItem = []
for i in col:
    listItem.append([i, 
                    df[i].dtype,
                    df[i].nunique()])

dfDesc = pd.DataFrame(columns=['Column Name', 'Data Type', 'Number of Unique'],
                     data=listItem)
dfDesc.sort_values('Number of Unique', ascending =False)
# Out:
#       Column Name Data Type  Number of Unique
# 2              l3    object              1209
# 1              l2    object                43
# 3   property_type    object                10
# 0              l1    object                 4
# 4  operation_type    object                 3

# %%
df_1 = df.copy()
df_1
# Out:
#               lat        lon         l1                        l2  \
# 23     -34.400188 -58.724054  Argentina  Bs.As. G.B.A. Zona Norte
# 28     -24.825768 -65.470791  Argentina                     Salta
# 29     -38.982898 -68.350754  Argentina                   Neuquén
# 30     -38.948296 -68.265567  Argentina                   Neuquén
# 31     -34.602164 -58.375030  Argentina           Capital Federal
# ...           ...        ...        ...                       ...
# 999995 -34.900186 -56.176744    Uruguay                Montevideo
# 999996 -34.886879 -56.188048    Uruguay                Montevideo
# 999997 -34.891367 -56.098215    Uruguay                Montevideo
# 999998 -34.462092 -57.842109    Uruguay                   Colonia
# 999999 -34.885796 -56.089121    Uruguay                Montevideo
#
#                    l3  rooms  bedrooms  bathrooms  surface_total  \
# 23            Escobar    4.0       2.0        1.0     514.889481
# 28              Salta    3.0       2.0        1.0     324.000000
# 29        Confluencia    3.0       2.0        1.0     250.000000
# 30        Confluencia    3.0       2.0        1.0     360.000000
# 31        San Nicolás    3.0       2.0        2.0     160.000000
# ...               ...    ...       ...        ...            ...
# 999995  Mar del Plata    3.0       2.0        2.0      58.000000
# 999996  Mar del Plata    1.0       2.0        1.0      62.000000
# 999997  Mar del Plata    4.0       3.0        2.0     514.889481
# 999998  Mar del Plata    5.0       3.0        1.0     135.000000
# 999999  Mar del Plata    3.0       3.0        2.0      78.000000
#
#         surface_covered    price property_type     operation_type
# 23                 98.0      0.0          Otro  Alquiler temporal
# 28                324.0  18000.0          Lote              Venta
# 29                250.0   7020.0          Lote              Venta
# 30                360.0  14850.0          Lote              Venta
# 31                160.0    450.0       Oficina           Alquiler
# ...                 ...      ...           ...                ...
# 999995             55.0    552.0  Departamento           Alquiler
# 999996             62.0    600.0  Departamento           Alquiler
# 999997             85.0   1152.0          Casa           Alquiler
# 999998            135.0    840.0          Casa           Alquiler
# 999999             78.0    816.0  Departamento           Alquiler
#
# [963098 rows x 13 columns]

# %%
df.drop(columns='l3', inplace= True)

# %%
df.head()
# Out:
#           lat        lon         l1                        l2  rooms  \
# 23 -34.400188 -58.724054  Argentina  Bs.As. G.B.A. Zona Norte    4.0
# 28 -24.825768 -65.470791  Argentina                     Salta    3.0
# 29 -38.982898 -68.350754  Argentina                   Neuquén    3.0
# 30 -38.948296 -68.265567  Argentina                   Neuquén    3.0
# 31 -34.602164 -58.375030  Argentina           Capital Federal    3.0
#
#     bedrooms  bathrooms  surface_total  surface_covered    price  \
# 23       2.0        1.0     514.889481             98.0      0.0
# 28       2.0        1.0     324.000000            324.0  18000.0
# 29       2.0        1.0     250.000000            250.0   7020.0
# 30       2.0        1.0     360.000000            360.0  14850.0
# 31       2.0        2.0     160.000000            160.0    450.0
#
#    property_type     operation_type
# 23          Otro  Alquiler temporal
# 28          Lote              Venta
# 29          Lote              Venta
# 30          Lote              Venta
# 31       Oficina           Alquiler

# %%
df_1.drop(columns = 'l3', inplace =True)

# %%
df_1 = pd.get_dummies(df_1, columns=['l1', 'l2', 'property_type', 'operation_type'])

# %%
df_1.head()
# Out:
#           lat        lon  rooms  bedrooms  bathrooms  surface_total  \
# 23 -34.400188 -58.724054    4.0       2.0        1.0     514.889481
# 28 -24.825768 -65.470791    3.0       2.0        1.0     324.000000
# 29 -38.982898 -68.350754    3.0       2.0        1.0     250.000000
# 30 -38.948296 -68.265567    3.0       2.0        1.0     360.000000
# 31 -34.602164 -58.375030    3.0       2.0        2.0     160.000000
#
#     surface_covered    price  l1_Argentina  l1_Brasil  ...  \
# 23             98.0      0.0             1          0  ...
# 28            324.0  18000.0             1          0  ...
# 29            250.0   7020.0             1          0  ...
# 30            360.0  14850.0             1          0  ...
# 31            160.0    450.0             1          0  ...
#
#     property_type_Departamento  property_type_Depósito  \
# 23                           0                       0
# 28                           0                       0
# 29                           0                       0
# 30                           0                       0
# 31                           0                       0
#
#     property_type_Local comercial  property_type_Lote  property_type_Oficina  \
# 23                              0                   0                      0
# 28                              0                   1                      0
# 29                              0                   1                      0
# 30                              0                   1                      0
# 31                              0                   0                      1
#
#     property_type_Otro  property_type_PH  operation_type_Alquiler  \
# 23                   1                 0                        0
# 28                   0                 0                        0
# 29                   0                 0                        0
# 30                   0                 0                        0
# 31                   0                 0                        1
#
#     operation_type_Alquiler temporal  operation_type_Venta
# 23                                 1                     0
# 28                                 0                     1
# 29                                 0                     1
# 30                                 0                     1
# 31                                 0                     0
#
# [5 rows x 68 columns]

# %%
## Model Machine Learning

# %%
# Menentukan Target dan features
X = df_1.drop(columns = ['price'])
y = df_1['price']

# %%
# Splitting Data train dan test
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size = .80, random_state = 42)

# %%
## def function modelling dan hasil evaluation matrix
def Eva_Matrix_DF(model, X_train, X_test, y_train, y_test, Nama):
    Model = model.fit(X_train, y_train)
    y_pred_tr = Model.predict(X_train)
    R2_tr = r2_score(y_train, y_pred_tr)
    MAE_tr = mean_absolute_error(y_train, y_pred_tr)
    MSE_tr = mean_squared_error(y_train, y_pred_tr)
    RMSE_tr = np.sqrt(MSE_tr)
    y_pred_ts = Model.predict(X_test)
    R2_ts = r2_score(y_test, y_pred_ts)
    MAE_ts = mean_absolute_error(y_test, y_pred_ts)
    MSE_ts = mean_squared_error(y_test, y_pred_ts)
    RMSE_ts = np.sqrt(MSE_ts)
    data = {
    "Training " + Nama : [R2_tr, MAE_tr, MSE_tr, RMSE_tr],
    "Testing " + Nama: [R2_ts, MAE_ts, MSE_ts, RMSE_ts]}
    df = pd.DataFrame(data = data, index = ['R2', 'MAE', 'MSE', 'RMSE'])
    return df

# %%
# Regresi menggunakan Linear regression
df_1_LinReg = Eva_Matrix_DF(LinearRegression(fit_intercept=False), X_train, X_test, y_train, y_test, "LinReg")

# %%
df_1_LinReg
# Out:
#       Training LinReg  Testing LinReg
# R2       1.878000e-04    1.177324e-01
# MAE      1.467627e+05    1.326484e+05
# MSE      1.301410e+14    1.402277e+11
# RMSE     1.140794e+07    3.744698e+05

# %%
# Regresi menggunakan Ridge
df_1_Ridge = Eva_Matrix_DF(Ridge(), X_train, X_test, y_train, y_test, "Ridge")

# %%
df_1_Ridge
# Out:
#       Training Ridge  Testing Ridge
# R2      1.878000e-04   1.177314e-01
# MAE     1.467608e+05   1.326463e+05
# MSE     1.301410e+14   1.402278e+11
# RMSE    1.140794e+07   3.744700e+05

# %%
# Regresi menggunakan Lasso
df_1_Lasso = Eva_Matrix_DF(Lasso(), X_train, X_test, y_train, y_test, "Lasso")

# %%
df_1_Lasso
# Out:
#       Training Lasso  Testing Lasso
# R2      1.877986e-04   1.177090e-01
# MAE     1.467529e+05   1.326374e+05
# MSE     1.301410e+14   1.402314e+11
# RMSE    1.140794e+07   3.744748e+05

# %%
# Regresi menggunakan ElasticNet
df_1_ElasticNet = Eva_Matrix_DF(ElasticNet(), X_train, X_test, y_train, y_test, "Lasso")
df_1_ElasticNet
# Out:
#       Training Lasso  Testing Lasso
# R2      1.343327e-04   8.946932e-02
# MAE     1.432801e+05   1.295163e+05
# MSE     1.301480e+14   1.447198e+11
# RMSE    1.140824e+07   3.804205e+05

# %%
pd.concat([df_1_LinReg, df_1_Ridge, df_1_Lasso, df_1_ElasticNet], axis = 1).T.sort_values('R2', ascending =False)
# Out:
#                        R2            MAE           MSE          RMSE
# Testing LinReg   0.117732  132648.414527  1.402277e+11  3.744698e+05
# Testing Ridge    0.117731  132646.343631  1.402278e+11  3.744700e+05
# Testing Lasso    0.117709  132637.421856  1.402314e+11  3.744748e+05
# Testing Lasso    0.089469  129516.340275  1.447198e+11  3.804205e+05
# Training LinReg  0.000188  146762.703019  1.301410e+14  1.140794e+07
# Training Ridge   0.000188  146760.816491  1.301410e+14  1.140794e+07
# Training Lasso   0.000188  146752.863270  1.301410e+14  1.140794e+07
# Training Lasso   0.000134  143280.082981  1.301480e+14  1.140824e+07

# %% [markdown]
# ## Feature Engineering

# %%
## Scalling

# %%
scaler = MinMaxScaler()
scaler.fit(X_train) # preprocess fit
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
## mencoba regresi dengan Lasso

# %%
# Regresi menggunakan Lasso
df_scl_Lasso = Eva_Matrix_DF(Lasso(), X_train_scaled, X_test_scaled, y_train, y_test, "Lasso")

# %%
df_scl_Lasso
# Out:
#       Training Lasso  Testing Lasso
# R2      1.881156e-04   1.245059e-01
# MAE     1.467084e+05   1.325494e+05
# MSE     1.299391e+14   1.280817e+11
# RMSE    1.139908e+07   3.578851e+05

# %%
## Polynomial Regression
poly = PolynomialFeatures(degree=3, include_bias=False)
yeo_pow = PowerTransformer(method='yeo-johnson')

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 963098 entries, 23 to 999999
# Data columns (total 68 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   lat                               963098 non-null  float64
#  1   lon                               963098 non-null  float64
#  2   rooms                             963098 non-null  float64
#  3   bedrooms                          963098 non-null  float64
#  4   bathrooms                         963098 non-null  float64
#  5   surface_total                     963098 non-null  float64
#  6   surface_covered                   963098 non-null  float64
#  7   price                             963098 non-null  float64
#  8   l1_Argentina                      963098 non-null  uint8
#  9   l1_Brasil                         963098 non-null  uint8
#  10  l1_Estados Unidos                 963098 non-null  uint8
#  11  l1_Uruguay                        963098 non-null  uint8
#  12  l2_Bs.As. G.B.A. Zona Norte       963098 non-null  uint8
#  13  l2_Bs.As. G.B.A. Zona Oeste       963098 non-null  uint8
#  14  l2_Bs.As. G.B.A. Zona Sur         963098 non-null  uint8
#  15  l2_Buenos Aires Costa Atlántica   963098 non-null  uint8
#  16  l2_Buenos Aires Interior          963098 non-null  uint8
#  17  l2_Canelones                      963098 non-null  uint8
#  18  l2_Capital Federal                963098 non-null  uint8
#  19  l2_Catamarca                      963098 non-null  uint8
#  20  l2_Chaco                          963098 non-null  uint8
#  21  l2_Chubut                         963098 non-null  uint8
#  22  l2_Colonia                        963098 non-null  uint8
#  23  l2_Corrientes                     963098 non-null  uint8
#  24  l2_Córdoba                        963098 non-null  uint8
#  25  l2_Entre Ríos                     963098 non-null  uint8
#  26  l2_Florida                        963098 non-null  uint8
#  27  l2_Formosa                        963098 non-null  uint8
#  28  l2_Jujuy                          963098 non-null  uint8
#  29  l2_La Pampa                       963098 non-null  uint8
#  30  l2_La Rioja                       963098 non-null  uint8
#  31  l2_Maldonado                      963098 non-null  uint8
#  32  l2_Maryland                       963098 non-null  uint8
#  33  l2_Mendoza                        963098 non-null  uint8
#  34  l2_Miami                          963098 non-null  uint8
#  35  l2_Michigan                       963098 non-null  uint8
#  36  l2_Misiones                       963098 non-null  uint8
#  37  l2_Montevideo                     963098 non-null  uint8
#  38  l2_Neuquén                        963098 non-null  uint8
#  39  l2_New York                       963098 non-null  uint8
#  40  l2_Pennsylvania                   963098 non-null  uint8
#  41  l2_Rio Grande do Norte            963098 non-null  uint8
#  42  l2_Rio de Janeiro                 963098 non-null  uint8
#  43  l2_Rocha                          963098 non-null  uint8
#  44  l2_Río Negro                      963098 non-null  uint8
#  45  l2_Salta                          963098 non-null  uint8
#  46  l2_San Juan                       963098 non-null  uint8
#  47  l2_San Luis                       963098 non-null  uint8
#  48  l2_Santa Catarina                 963098 non-null  uint8
#  49  l2_Santa Cruz                     963098 non-null  uint8
#  50  l2_Santa Fe                       963098 non-null  uint8
#  51  l2_Santiago Del Estero            963098 non-null  uint8
#  52  l2_São Paulo                      963098 non-null  uint8
#  53  l2_Tierra Del Fuego               963098 non-null  uint8
#  54  l2_Tucumán                        963098 non-null  uint8
#  55  property_type_Casa                963098 non-null  uint8
#  56  property_type_Casa de campo       963098 non-null  uint8
#  57  property_type_Cochera             963098 non-null  uint8
#  58  property_type_Departamento        963098 non-null  uint8
#  59  property_type_Depósito            963098 non-null  uint8
#  60  property_type_Local comercial     963098 non-null  uint8
#  61  property_type_Lote                963098 non-null  uint8
#  62  property_type_Oficina             963098 non-null  uint8
#  63  property_type_Otro                963098 non-null  uint8
#  64  property_type_PH                  963098 non-null  uint8
#  65  operation_type_Alquiler           963098 non-null  uint8
#  66  operation_type_Alquiler temporal  963098 non-null  uint8
#  67  operation_type_Venta              963098 non-null  uint8
# dtypes: float64(8), uint8(60)
# memory usage: 121.2 MB

# %%
num_col = df[['lat', 'lon', 'surface_total', 'surface_covered']]

# %%
n = df_1[df_1['price'] == 0]
n
# Out:
#               lat        lon  rooms  bedrooms  bathrooms  surface_total  \
# 23     -34.400188 -58.724054    4.0       2.0        1.0     514.889481
# 430    -38.061534 -57.547720    3.0       2.0        1.0     514.889481
# 1699   -34.790048 -59.256701    3.0       2.0        1.0     514.889481
# 1990   -40.154585 -71.354476    2.0       1.0        1.0     514.889481
# 4930   -34.578272 -58.441348    2.0       1.0        1.0     514.889481
# ...           ...        ...    ...       ...        ...            ...
# 996869 -34.577712 -58.436266    3.0       2.0        1.0      91.000000
# 996870 -34.577712 -58.436266    3.0       2.0        1.0      91.000000
# 996875 -26.826181 -65.314981    3.0       2.0        2.0     120.000000
# 996879 -34.790048 -59.256701    6.0       3.0        1.0     514.889481
# 996884 -34.540395 -58.464042    4.0       3.0        2.0     188.000000
#
#         surface_covered  price  l1_Argentina  l1_Brasil  ...  \
# 23            98.000000    0.0             1          0  ...
# 430         6123.054086    0.0             1          0  ...
# 1699        6123.054086    0.0             1          0  ...
# 1990        6123.054086    0.0             1          0  ...
# 4930        6123.054086    0.0             1          0  ...
# ...                 ...    ...           ...        ...  ...
# 996869        78.000000    0.0             1          0  ...
# 996870        78.000000    0.0             1          0  ...
# 996875       120.000000    0.0             1          0  ...
# 996879      6123.054086    0.0             1          0  ...
# 996884       156.000000    0.0             1          0  ...
#
#         property_type_Departamento  property_type_Depósito  \
# 23                               0                       0
# 430                              0                       0
# 1699                             0                       0
# 1990                             1                       0
# 4930                             1                       0
# ...                            ...                     ...
# 996869                           1                       0
# 996870                           1                       0
# 996875                           1                       0
# 996879                           0                       0
# 996884                           1                       0
#
#         property_type_Local comercial  property_type_Lote  \
# 23                                  0                   0
# 430                                 0                   0
# 1699                                0                   1
# 1990                                0                   0
# 4930                                0                   0
# ...                               ...                 ...
# 996869                              0                   0
# 996870                              0                   0
# 996875                              0                   0
# 996879                              0                   0
# 996884                              0                   0
#
#         property_type_Oficina  property_type_Otro  property_type_PH  \
# 23                          0                   1                 0
# 430                         0                   0                 0
# 1699                        0                   0                 0
# 1990                        0                   0                 0
# 4930                        0                   0                 0
# ...                       ...                 ...               ...
# 996869                      0                   0                 0
# 996870                      0                   0                 0
# 996875                      0                   0                 0
# 996879                      0                   0                 1
# 996884                      0                   0                 0
#
#         operation_type_Alquiler  operation_type_Alquiler temporal  \
# 23                            0                                 1
# 430                           0                                 1
# 1699                          0                                 0
# 1990                          0                                 0
# 4930                          0                                 0
# ...                         ...                               ...
# 996869                        0                                 0
# 996870                        0                                 0
# 996875                        1                                 0
# 996879                        1                                 0
# 996884                        0                                 0
#
#         operation_type_Venta
# 23                         0
# 430                        0
# 1699                       1
# 1990                       1
# 4930                       1
# ...                      ...
# 996869                     1
# 996870                     1
# 996875                     0
# 996879                     0
# 996884                     1
#
# [1517 rows x 68 columns]

# %%
df_1.drop(n.index, inplace = True)
